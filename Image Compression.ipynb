# %%
import matplotlib.pyplot as plt

# %%
RGB_img = plt.imread("AQUA.png")

# %%
print(type(RGB_img))
print(RGB_img.shape)
# Out:
# <class 'numpy.ndarray'>
# (750, 750, 4)

# %%
plt.imshow(RGB_img)

# %% [markdown]
# ### Splitting the image into color channels

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 53.9 MB 733 kB/s eta 0:00:01    |████▍                           | 7.3 MB 287 kB/s eta 0:02:42
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
b, g, r, bitch = cv2.split(RGB_img)

# %%
plt.imshow(b)

# %%
plt.imshow(cv2.split(RGB_img)[0])
